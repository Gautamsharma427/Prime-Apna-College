# %%
import numpy as np #importing numpy as np 
# numpy can be installed using "pip install numpy"

#Creating a Numpy array , '''takes in a list''
arr = np.array([1,2,3,4,5,6])
print(arr,type(arr))
# Out:
# [1 2 3 4 5 6] <class 'numpy.ndarray'>

# %%
import time
# PYTHON LIST VS NUMPY ARRAYS
# 1. Numpy arrays are way faster than Python lists when we are operating on large datasets
# 2. Numpy stores data in continuous memory blocks which is not the same in python lists.
# 3. Uses Less memory/space than python lists
# 4. It has built in mathematical functions
# 5. Supports Vectorized Operations

# CREATING A PYTHON LIST
lst = list(range(1000000))
start = time.time()
sqr = [i*i for i in lst]
end = time.time()
print("Time Spent = ",end-start)


# CREATING A NUMPY ARRAY FROM THE PYTHON LIST
np_array = np.array(lst)
start = time.time()
sqr_array = np_array ** 2
end = time.time()
print("Time Taken is ",end-start)
# So NP array is very fast
#--------------------------------------------------------------------------------
print("The Storagef of a python list is:", sys.getsizeof(lst)*len(lst)," bytes") #sys module is used to get the bytes consumed by a list using the getsizeof() method.
print("The storage of a Numpy array is:", np_array.nbytes)#.nbytes is a default for getting the amount of bytes consumend by a numpy-array in python 
# So NP array is very less space consuming than python lists
#---------------------------------------------------------------------------------
# Out:
# Time Spent =  0.06892609596252441
# Time Taken is  0.002832651138305664
# The Storagef of a python list is: 8000056000000  bytes
# The storage of a Numpy array is: 8000000
